# %%
# config & setup 
import os, json, datetime, asyncio
from pathlib import Path
from dotenv import load_dotenv

load_dotenv("../.env")
api_id = int(os.getenv("TELEGRAM_API_ID"))
api_hash = os.getenv("TELEGRAM_API_HASH")
session_name = os.getenv("TELEGRAM_SESSION", "telegram_session")

CHANNELS = ["@CheMed123", "@lobelia4cosmetics", "@tikvahpharma"]

# Force full backfill for all channels (ignore state)
FORCE_FULL = ["@CheMed123", "@lobelia4cosmetics", "@tikvahpharma"]

BACKFILL_PAGE_SIZE = 100   # smaller = gentler on rate limits and flaky networks

today = datetime.date.today().isoformat()
BASE = Path("..")
MSG_DIR = BASE / "data" / "raw" / "telegram_messages" / today
IMG_DIR = BASE / "data" / "raw" / "images" / today
STATE_FILE = BASE / ".state" / "scrape_state.json"

MSG_DIR.mkdir(parents=True, exist_ok=True)
IMG_DIR.mkdir(parents=True, exist_ok=True)
STATE_FILE.parent.mkdir(parents=True, exist_ok=True)

def load_state():
    if STATE_FILE.exists():
        try:
            return json.loads(STATE_FILE.read_text(encoding="utf-8"))
        except Exception:
            return {}
    return {}

def save_state(state: dict):
    STATE_FILE.write_text(json.dumps(state, indent=2), encoding="utf-8")

state = load_state()
print("Will write JSON under:", MSG_DIR)
print("Will write images under:", IMG_DIR)
# Out:
# Will write JSON under: ..\data\raw\telegram_messages\2025-08-21
# Will write images under: ..\data\raw\images\2025-08-21

# %%
#  FULL backfill (ignores state) 
from telethon import TelegramClient
from telethon.tl.types import MessageMediaPhoto
from telethon.errors.rpcerrorlist import FloodWaitError
from pathlib import Path
import datetime, asyncio

def write_json(channel_name: str, records: list):
    out_json = MSG_DIR / f"{channel_name}.json"
    out_json.parent.mkdir(parents=True, exist_ok=True)
    out_json.write_text(json.dumps(records, ensure_ascii=False, indent=2), encoding="utf-8")
    return out_json

async def scrape_full_history(client: TelegramClient, channel: str):
    ch_name = channel.strip("@")
    ch_img_dir = IMG_DIR / ch_name
    ch_img_dir.mkdir(parents=True, exist_ok=True)

    out = []
    offset_id = 0
    total = 0

    print(f" FULL backfill {channel} (ignoring state) ...")
    while True:
        batch = 0
        try:
            async for msg in client.iter_messages(channel, limit=BACKFILL_PAGE_SIZE, offset_id=offset_id):
                rec = {
                    "id": int(msg.id),
                    "channel_name": ch_name,
                    "message_text": getattr(msg, "message", None),
                    "message_date": msg.date.isoformat() if msg.date else None,
                    "has_image": False,
                    "image_path": None,
                }
                if isinstance(msg.media, MessageMediaPhoto):
                    try:
                        file_path = (ch_img_dir / f"{msg.id}").as_posix()
                        saved = await msg.download_media(file=file_path)
                        if saved:
                            rel = Path(saved).resolve().relative_to(Path("..").resolve())
                            rec["has_image"] = True
                            rec["image_path"] = rel.as_posix()
                    except Exception as e:
                        print(f"[WARN] {channel} msg {msg.id}: image download failed: {e}")

                out.append(rec)
                offset_id = msg.id
                batch += 1
                total += 1

        except FloodWaitError as e:
            print(f"[RATE LIMIT] {channel}: sleeping {e.seconds}s ...")
            await asyncio.sleep(e.seconds + 5)
            continue
        except Exception as e:
            print(f"[ERROR] {channel}: {e}; retrying current page ...")
            await asyncio.sleep(3)
            continue

        print(f"  fetched batch={batch} (offset_id now {offset_id}), total={total}")
        if batch == 0:
            break  # no more messages

    out_json = write_json(ch_name, out)
    print(f"FULL saved {total} → {out_json}")

    if out:
        max_id = max(m["id"] for m in out)
        state[channel] = {"last_id": max_id, "last_run": datetime.datetime.utcnow().isoformat()}
        save_state(state)

async def run_backfill():
    async with TelegramClient(session_name, api_id, api_hash) as client:
        for ch in FORCE_FULL:
            await scrape_full_history(client, ch)
    print(" Full backfill complete for:", FORCE_FULL)

await run_backfill()
# Out:
#  FULL backfill @CheMed123 (ignoring state) ...
#   fetched batch=76 (offset_id now 1), total=76
#   fetched batch=0 (offset_id now 1), total=76
# FULL saved 76 → ..\data\raw\telegram_messages\2025-08-21\CheMed123.json
#  FULL backfill @lobelia4cosmetics (ignoring state) ...
#   fetched batch=100 (offset_id now 19178), total=100
#   fetched batch=100 (offset_id now 19074), total=200
#   fetched batch=100 (offset_id now 18969), total=300
#   fetched batch=100 (offset_id now 18859), total=400
#   fetched batch=100 (offset_id now 18751), total=500
#   fetched batch=100 (offset_id now 18645), total=600
#   fetched batch=100 (offset_id now 18544), total=700
#   fetched batch=100 (offset_id now 18440), total=800
#   fetched batch=100 (offset_id now 18336), total=900
#   fetched batch=100 (offset_id now 18228), total=1000
#   fetched batch=100 (offset_id now 18121), total=1100
#   fetched batch=100 (offset_id now 18015), total=1200
#   fetched batch=100 (offset_id now 17914), total=1300
#   fetched batch=100 (offset_id now 17812), total=1400
#   fetched batch=100 (offset_id now 17709), total=1500
#   fetched batch=100 (offset_id now 17607), total=1600
#   fetched batch=100 (offset_id now 17507), total=1700
#   fetched batch=17 (offset_id now 1), total=1717
#   fetched batch=0 (offset_id now 1), total=1717
# FULL saved 1717 → ..\data\raw\telegram_messages\2025-08-21\lobelia4cosmetics.json
#  FULL backfill @tikvahpharma (ignoring state) ...
#   fetched batch=100 (offset_id now 175838), total=100
#   fetched batch=100 (offset_id now 175437), total=200
#   fetched batch=100 (offset_id now 175104), total=300
#   fetched batch=100 (offset_id now 174752), total=400
#   fetched batch=100 (offset_id now 174415), total=500
#   fetched batch=100 (offset_id now 174048), total=600
#   fetched batch=100 (offset_id now 173713), total=700
#   fetched batch=100 (offset_id now 173410), total=800
#   fetched batch=100 (offset_id now 173124), total=900
#   fetched batch=100 (offset_id now 172809), total=1000
#   fetched batch=100 (offset_id now 172442), total=1100
#   fetched batch=100 (offset_id now 172090), total=1200
#   fetched batch=100 (offset_id now 171940), total=1300
#   fetched batch=100 (offset_id now 171814), total=1400
#   fetched batch=100 (offset_id now 171712), total=1500
#   fetched batch=100 (offset_id now 171421), total=1600
#   fetched batch=100 (offset_id now 171116), total=1700
#   fetched batch=100 (offset_id now 170737), total=1800
#   fetched batch=100 (offset_id now 170246), total=1900
#   fetched batch=100 (offset_id now 169819), total=2000
#   fetched batch=100 (offset_id now 169239), total=2100
#   fetched batch=100 (offset_id now 167910), total=2200
#   fetched batch=100 (offset_id now 167282), total=2300
#   fetched batch=100 (offset_id now 166492), total=2400
#   fetched batch=100 (offset_id now 165789), total=2500
#   fetched batch=100 (offset_id now 165190), total=2600
#   fetched batch=100 (offset_id now 164327), total=2700
#   fetched batch=100 (offset_id now 163931), total=2800
#   fetched batch=100 (offset_id now 163262), total=2900
#   fetched batch=100 (offset_id now 162259), total=3000
#   fetched batch=100 (offset_id now 161789), total=3100
#   fetched batch=100 (offset_id now 161301), total=3200
#   fetched batch=100 (offset_id now 160503), total=3300
#   fetched batch=100 (offset_id now 159673), total=3400
#   fetched batch=100 (offset_id now 158826), total=3500
#   fetched batch=100 (offset_id now 158098), total=3600
#   fetched batch=100 (offset_id now 157407), total=3700
#   fetched batch=100 (offset_id now 157218), total=3800
#   fetched batch=100 (offset_id now 156419), total=3900
#   fetched batch=100 (offset_id now 155936), total=4000
#   fetched batch=100 (offset_id now 155366), total=4100
#   fetched batch=100 (offset_id now 154346), total=4200
#   fetched batch=100 (offset_id now 153760), total=4300
#   fetched batch=100 (offset_id now 153145), total=4400
#   fetched batch=100 (offset_id now 152565), total=4500
#   fetched batch=100 (offset_id now 152058), total=4600
#   fetched batch=100 (offset_id now 151556), total=4700
#   fetched batch=100 (offset_id now 151007), total=4800
#   fetched batch=100 (offset_id now 150405), total=4900
#   fetched batch=100 (offset_id now 149505), total=5000
#   fetched batch=100 (offset_id now 149270), total=5100
#   fetched batch=100 (offset_id now 148980), total=5200
#   fetched batch=100 (offset_id now 148638), total=5300
#   fetched batch=100 (offset_id now 148265), total=5400
#   fetched batch=100 (offset_id now 147924), total=5500
#   fetched batch=100 (offset_id now 147553), total=5600
#   fetched batch=100 (offset_id now 147204), total=5700
#   fetched batch=100 (offset_id now 146884), total=5800
#   fetched batch=100 (offset_id now 146733), total=5900
#   fetched batch=100 (offset_id now 146511), total=6000
#   fetched batch=100 (offset_id now 146059), total=6100
#   fetched batch=100 (offset_id now 145536), total=6200
#   fetched batch=100 (offset_id now 145317), total=6300
#   fetched batch=100 (offset_id now 145214), total=6400
#   fetched batch=100 (offset_id now 145109), total=6500
#   fetched batch=100 (offset_id now 144985), total=6600
#   fetched batch=100 (offset_id now 144234), total=6700
#   fetched batch=100 (offset_id now 142538), total=6800
#   fetched batch=100 (offset_id now 141741), total=6900
#   fetched batch=100 (offset_id now 141244), total=7000
#   fetched batch=100 (offset_id now 140836), total=7100
#   fetched batch=100 (offset_id now 140387), total=7200
#   fetched batch=100 (offset_id now 139967), total=7300
#   fetched batch=100 (offset_id now 139528), total=7400
#   fetched batch=100 (offset_id now 139039), total=7500
#   fetched batch=100 (offset_id now 138499), total=7600
#   fetched batch=100 (offset_id now 138037), total=7700
#   fetched batch=100 (offset_id now 137553), total=7800
#   fetched batch=100 (offset_id now 137281), total=7900
#   fetched batch=100 (offset_id now 137028), total=8000
#   fetched batch=100 (offset_id now 136493), total=8100
#   fetched batch=100 (offset_id now 136294), total=8200
#   fetched batch=100 (offset_id now 135858), total=8300
#   fetched batch=100 (offset_id now 135343), total=8400
#   fetched batch=100 (offset_id now 134875), total=8500
#   fetched batch=100 (offset_id now 134417), total=8600
#   fetched batch=100 (offset_id now 133986), total=8700
#   fetched batch=100 (offset_id now 133685), total=8800
#   fetched batch=100 (offset_id now 133292), total=8900
#   fetched batch=100 (offset_id now 132966), total=9000
#   fetched batch=100 (offset_id now 132604), total=9100
#   fetched batch=100 (offset_id now 132192), total=9200
#   fetched batch=100 (offset_id now 131864), total=9300
#   fetched batch=100 (offset_id now 131470), total=9400
#   fetched batch=100 (offset_id now 131337), total=9500
#   fetched batch=100 (offset_id now 131210), total=9600
#   fetched batch=100 (offset_id now 131097), total=9700
#   fetched batch=100 (offset_id now 130754), total=9800
#   fetched batch=100 (offset_id now 130402), total=9900
#   fetched batch=100 (offset_id now 130042), total=10000
#   fetched batch=100 (offset_id now 129646), total=10100
#   fetched batch=100 (offset_id now 129315), total=10200
#   fetched batch=100 (offset_id now 128949), total=10300
#   fetched batch=100 (offset_id now 128493), total=10400
#   fetched batch=100 (offset_id now 128075), total=10500
#   fetched batch=100 (offset_id now 127682), total=10600
#   fetched batch=100 (offset_id now 127252), total=10700
#   fetched batch=100 (offset_id now 126889), total=10800
#   fetched batch=100 (offset_id now 126510), total=10900
#   fetched batch=100 (offset_id now 125888), total=11000
#   fetched batch=100 (offset_id now 125227), total=11100
#   fetched batch=100 (offset_id now 124435), total=11200
#   fetched batch=100 (offset_id now 123870), total=11300
#   fetched batch=100 (offset_id now 123207), total=11400
#   fetched batch=100 (offset_id now 122640), total=11500
#   fetched batch=100 (offset_id now 122006), total=11600
#   fetched batch=100 (offset_id now 121289), total=11700
#   fetched batch=100 (offset_id now 120910), total=11800
#   fetched batch=100 (offset_id now 120328), total=11900
#   fetched batch=100 (offset_id now 119683), total=12000
#   fetched batch=100 (offset_id now 119050), total=12100
#   fetched batch=100 (offset_id now 118590), total=12200
#   fetched batch=100 (offset_id now 117897), total=12300
#   fetched batch=100 (offset_id now 117270), total=12400
#   fetched batch=100 (offset_id now 116308), total=12500
#   fetched batch=100 (offset_id now 115751), total=12600
#   fetched batch=100 (offset_id now 115055), total=12700
#   fetched batch=100 (offset_id now 114338), total=12800
#   fetched batch=100 (offset_id now 113381), total=12900
#   fetched batch=100 (offset_id now 112700), total=13000
#   fetched batch=100 (offset_id now 111916), total=13100
#   fetched batch=100 (offset_id now 110903), total=13200
#   fetched batch=100 (offset_id now 110043), total=13300
#   fetched batch=100 (offset_id now 109229), total=13400
#   fetched batch=100 (offset_id now 108574), total=13500
#   fetched batch=100 (offset_id now 107882), total=13600
#   fetched batch=100 (offset_id now 106787), total=13700
#   fetched batch=100 (offset_id now 106197), total=13800
#   fetched batch=100 (offset_id now 70160), total=13900
#   fetched batch=100 (offset_id now 61905), total=14000
#   fetched batch=100 (offset_id now 53933), total=14100
#   fetched batch=100 (offset_id now 48518), total=14200
#   fetched batch=100 (offset_id now 44804), total=14300
#   fetched batch=100 (offset_id now 42649), total=14400
#   fetched batch=100 (offset_id now 41673), total=14500
#   fetched batch=100 (offset_id now 40785), total=14600
#   fetched batch=100 (offset_id now 40038), total=14700
#   fetched batch=100 (offset_id now 38389), total=14800
#   fetched batch=100 (offset_id now 37479), total=14900
#   fetched batch=100 (offset_id now 36748), total=15000
#   fetched batch=100 (offset_id now 36041), total=15100
#   fetched batch=100 (offset_id now 35108), total=15200
#   fetched batch=100 (offset_id now 34177), total=15300
#   fetched batch=100 (offset_id now 33288), total=15400
#   fetched batch=100 (offset_id now 31516), total=15500
#   fetched batch=100 (offset_id now 30687), total=15600
#   fetched batch=100 (offset_id now 30074), total=15700
#   fetched batch=100 (offset_id now 29372), total=15800
#   fetched batch=100 (offset_id now 28806), total=15900
#   fetched batch=100 (offset_id now 28074), total=16000
#   fetched batch=100 (offset_id now 26304), total=16100
#   fetched batch=100 (offset_id now 25350), total=16200
#   fetched batch=100 (offset_id now 24415), total=16300
#   fetched batch=100 (offset_id now 23516), total=16400
#   fetched batch=100 (offset_id now 22270), total=16500
#   fetched batch=100 (offset_id now 20696), total=16600
#   fetched batch=100 (offset_id now 18098), total=16700
#   fetched batch=100 (offset_id now 17288), total=16800
#   fetched batch=100 (offset_id now 17115), total=16900
#   fetched batch=100 (offset_id now 16915), total=17000
#   fetched batch=100 (offset_id now 16647), total=17100
#   fetched batch=100 (offset_id now 16485), total=17200
#   fetched batch=100 (offset_id now 16351), total=17300
#   fetched batch=100 (offset_id now 16201), total=17400
#   fetched batch=100 (offset_id now 15970), total=17500
#   fetched batch=100 (offset_id now 15801), total=17600
#   fetched batch=100 (offset_id now 15667), total=17700
#   fetched batch=100 (offset_id now 15510), total=17800
#   fetched batch=100 (offset_id now 15410), total=17900
#   fetched batch=100 (offset_id now 15262), total=18000
#   fetched batch=100 (offset_id now 15002), total=18100
#   fetched batch=100 (offset_id now 14661), total=18200
#   fetched batch=100 (offset_id now 14460), total=18300
#   fetched batch=100 (offset_id now 14222), total=18400
#   fetched batch=100 (offset_id now 14014), total=18500
#   fetched batch=100 (offset_id now 13810), total=18600
#   fetched batch=100 (offset_id now 13586), total=18700
#   fetched batch=100 (offset_id now 13391), total=18800
#   fetched batch=100 (offset_id now 13258), total=18900
#   fetched batch=100 (offset_id now 13097), total=19000
#   fetched batch=100 (offset_id now 12841), total=19100
#   fetched batch=100 (offset_id now 12626), total=19200
#   fetched batch=100 (offset_id now 12423), total=19300
#   fetched batch=100 (offset_id now 12223), total=19400
#   fetched batch=100 (offset_id now 12068), total=19500
#   fetched batch=100 (offset_id now 11949), total=19600
#   fetched batch=100 (offset_id now 11710), total=19700
#   fetched batch=100 (offset_id now 11526), total=19800
#   fetched batch=100 (offset_id now 11302), total=19900
#   fetched batch=100 (offset_id now 11121), total=20000
#   fetched batch=100 (offset_id now 10995), total=20100
#   fetched batch=100 (offset_id now 10807), total=20200
#   fetched batch=100 (offset_id now 10688), total=20300
#   fetched batch=100 (offset_id now 10489), total=20400
#   fetched batch=100 (offset_id now 10340), total=20500
#   fetched batch=100 (offset_id now 10105), total=20600
#   fetched batch=100 (offset_id now 9936), total=20700
#   fetched batch=100 (offset_id now 9633), total=20800
#   fetched batch=100 (offset_id now 9499), total=20900
#   fetched batch=100 (offset_id now 9335), total=21000
#   fetched batch=100 (offset_id now 9099), total=21100
#   fetched batch=100 (offset_id now 8911), total=21200
#   fetched batch=100 (offset_id now 8762), total=21300
#   fetched batch=100 (offset_id now 8598), total=21400
#   fetched batch=100 (offset_id now 8412), total=21500
#   fetched batch=100 (offset_id now 8273), total=21600
#   fetched batch=100 (offset_id now 7742), total=21700
#   fetched batch=100 (offset_id now 7349), total=21800
#   fetched batch=100 (offset_id now 7182), total=21900
#   fetched batch=100 (offset_id now 6692), total=22000
#   fetched batch=100 (offset_id now 6547), total=22100
#   fetched batch=100 (offset_id now 6414), total=22200
#   fetched batch=100 (offset_id now 6296), total=22300
#   fetched batch=100 (offset_id now 6148), total=22400
#   fetched batch=100 (offset_id now 6021), total=22500
#   fetched batch=100 (offset_id now 5890), total=22600
#   fetched batch=100 (offset_id now 5744), total=22700
#   fetched batch=100 (offset_id now 5617), total=22800
#   fetched batch=100 (offset_id now 5472), total=22900
#   fetched batch=100 (offset_id now 5320), total=23000
#   fetched batch=100 (offset_id now 5163), total=23100
#   fetched batch=100 (offset_id now 5000), total=23200
#   fetched batch=100 (offset_id now 4822), total=23300
#   fetched batch=100 (offset_id now 4677), total=23400
#   fetched batch=100 (offset_id now 4508), total=23500
#   fetched batch=100 (offset_id now 4348), total=23600
#   fetched batch=100 (offset_id now 4190), total=23700
#   fetched batch=100 (offset_id now 3998), total=23800
#   fetched batch=100 (offset_id now 3818), total=23900
#   fetched batch=100 (offset_id now 3628), total=24000
#   fetched batch=100 (offset_id now 3468), total=24100
#   fetched batch=100 (offset_id now 3353), total=24200
#   fetched batch=100 (offset_id now 3139), total=24300
#   fetched batch=100 (offset_id now 2823), total=24400
#   fetched batch=100 (offset_id now 2475), total=24500
#   fetched batch=100 (offset_id now 2104), total=24600
#   fetched batch=100 (offset_id now 1706), total=24700
#   fetched batch=100 (offset_id now 1541), total=24800
#   fetched batch=100 (offset_id now 1402), total=24900
#   fetched batch=100 (offset_id now 1220), total=25000
#   fetched batch=100 (offset_id now 1070), total=25100
#   fetched batch=100 (offset_id now 761), total=25200
#   fetched batch=100 (offset_id now 131), total=25300
#   fetched batch=93 (offset_id now 1), total=25393
#   fetched batch=0 (offset_id now 1), total=25393
# FULL saved 25393 → ..\data\raw\telegram_messages\2025-08-21\tikvahpharma.json
# 🏁 Full backfill complete for: ['@CheMed123', '@lobelia4cosmetics', '@tikvahpharma']
